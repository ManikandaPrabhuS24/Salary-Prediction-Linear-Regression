# %%
# Salary Prediction Using Simple Linear Regression
#Author: MANIKANDAPRABHU.S  
#Objective: Predict salary based on years of experience using Machine Learning.

# %%
# 1. Importing Required Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 2. Loading the Dataset
dataset=pd.read_csv("Salary_Data.csv")
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
# 3. Preparing Features and Target Variable
Features = dataset[["YearsExperience"]]
Target = dataset[["Salary"]]
Features.head()
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2

# %%
# 4. Splitting Data into Training and Testing Sets
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(Features,Target,test_size=1/3,random_state=0)
x_test
# Out:
#     YearsExperience
# 2               1.5
# 28             10.3
# 13              4.1
# 10              3.9
# 26              9.5
# 24              8.7
# 27              9.6
# 11              4.0
# 17              5.3
# 22              7.9

# %%
# 5. Training the Linear Regression Model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# 6. Model Prediction
y_pred = model.predict(x_test)

# %%
# 7. Model Evaluation
from sklearn.metrics import r2_score, mean_squared_error
print("R2 Score:", r2_score(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))

#Metric Used: R² Score to measure goodness of fit.
# Out:
# R2 Score: 0.9749154407708353
# MSE: 21026037.329511296

# %%
# 8. Visualizing Regression Results

# 8. Visualizing Regression Results (Training Set)
plt.figure(figsize=(8, 5))

# Scatter plot: Actual training data
plt.scatter(x_train, y_train)

# Regression line: Predicted values
plt.plot(x_train, model.predict(x_train),color='g')

plt.title("Salary vs Years of Experience (Training Set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
# Visualizing Test Set Results
plt.figure(figsize=(8, 5))

plt.scatter(x_test, y_test)
plt.plot(x_train, model.predict(x_train),color='g')

plt.title("Salary vs Years of Experience (Test Set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
# 9. Saving the Trained Model
import pickle
filename = "finalized_model.sav"
regressor=pickle.dump(model,open(filename,'wb'))

# %%
# Conclusion
#The model shows a strong positive linear relationship between years of experience and salary.
